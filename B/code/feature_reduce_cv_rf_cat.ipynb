# %%
#特征评价关键代码
import os
import matplotlib . pyplot as plt
import numpy as np
import pandas as pd

# %%
# data = pd.read_excel('../data/data_preprocess_only_45.xlsx')
# del data['Unnamed: 0']
# label = data['Product_RON_loss']
# del data['Product_RON_loss']

# %%
data = pd.read_excel('../data/data_var_corr_filtered_164.xlsx') #164对应只做45的， 165对应small,large且做了45
label = data['Product_RON_loss']
del data['Unnamed: 0']
del data['Product_RON_loss']

# %%
data.describe()
# Out:
#        Raw_S_content     Raw_RON  Raw_Saturated_hydrocarbon  Raw_Aromatics  \
# count     325.000000  325.000000                 325.000000     325.000000
# mean      229.548904   89.733538                  52.676228      21.949782
# std        65.752227    0.889764                   4.584314       1.823616
# min        57.000000   87.200000                  43.240000      16.822222
# 25%       185.000000   89.200000                  49.610000      20.690000
# 50%       240.285714   89.800000                  53.250000      21.890000
# 75%       271.428571   90.300000                  56.100000      23.300000
# max       392.000000   91.700000                  63.400000      26.200000
#
#        Raw_Bromine_value  Raw_Density  Product_S_content     Spent_C  \
# count         325.000000   325.000000         325.000000  325.000000
# mean           54.526661   726.755265           3.910154    3.030794
# std             6.818416     4.262181           1.265322    1.722995
# min            36.520000   715.100000           3.200000    1.010000
# 25%            48.750000   724.200000           3.200000    1.850000
# 50%            53.980000   726.300000           3.200000    2.390000
# 75%            60.190000   729.500000           4.200000    3.610000
# max            70.500000   738.700000           8.600000    9.090000
#
#           Spent_S   Recycle_C  ...  S-ZORB.TE_1102.DACA  \
# count  325.000000  325.000000  ...           325.000000
# mean     8.063265    1.507521  ...           426.623764
# std      2.132002    0.966428  ...             1.759060
# min      2.940000    0.250000  ...           420.898430
# 25%      6.990000    0.933333  ...           426.075162
# 50%      8.400000    1.280000  ...           427.171300
# 75%      9.370000    1.670000  ...           427.171300
# max     14.310000    5.190000  ...           432.095332
#
#        S-ZORB.AT-0001.DACA.PV  S-ZORB.AT-0003.DACA.PV  S-ZORB.FT_1204.DACA.PV  \
# count              325.000000              325.000000              325.000000
# mean                 2.547025                1.131551               51.913266
# std                  2.684052                1.147907               18.092283
# min                  0.498255                0.447884                0.889900
# 25%                  0.534488                0.464989               38.945485
# 50%                  0.555710                0.472675               51.672012
# 75%                  5.123928                1.391713               62.998978
# max                  7.155496                4.493657              106.657364
#
#        S-ZORB.FT_5102.DACA.PV  S-ZORB.CAL.LEVEL.PV  S-ZORB.FT_1006.DACA.PV  \
# count              325.000000           325.000000              325.000000
# mean                43.675943          1917.403402             4843.993930
# std                 48.877772          5287.204185             2359.134691
# min                  0.000000         -4269.455900                0.000000
# 25%                  0.000000            78.928243             4215.424100
# 50%                 64.004581            80.502553             5094.966775
# 75%                 67.964399            84.508473             6129.741900
# max                227.282440         18433.389250            11320.456750
#
#        S-ZORB.FT_5204.DACA.PV  S-ZORB.FT_1503.DACA.PV  S-ZORB.FT_1504.DACA.PV
# count              325.000000              325.000000              325.000000
# mean               143.854913             2190.862732             2409.550662
# std                137.450504              418.047777              452.316109
# min                  0.000000              979.564940             1222.663100
# 25%                  0.000000             1887.742875             2329.794550
# 50%                142.936557             2177.557700             2538.538450
# 75%                203.804645             2496.749950             2702.628700
# max                589.154615             3334.904725             3104.564825
#
# [8 rows x 164 columns]

# %%
# from sklearn.preprocessing import Normalizer
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# data = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)
# data.describe()

# %%
features = data.columns.values.tolist()

# %%
# # CV ranking
# cv_feature_importance = [( column, np. std ( data [column])/abs(np.mean(data[column]))) for column in features ]
# cv_feature_importance.sort (key=lambda x: x [1], reverse =True)
# cv_sorted_attrs = [item[0] for item in cv_feature_importance ]
# cv_ranking = [ cv_sorted_attrs . index(x) + 1 for x in features ]
# print ("# CV result")
# # print (cv_ranking)
# # print ( cv_feature_importance )

# %%
# cv_feature_sort = []
# cv_feature_score = []
# for i in range(0, len(cv_feature_importance)):
#     cv_feature_sort.append(cv_feature_importance[i][0])
#     cv_feature_score.append(cv_feature_importance[i][1])

# %%
# data_cv = pd.DataFrame(data, columns = cv_feature_sort[0:30]) 
# data_cv['Product_RON_loss'] = label

# %%
# data_cv.describe()

# %%
# data_cv.to_excel('../data/cv_top_30_data_process_45_var_corr_168.xlsx')

# %%
# # -*- coding: utf-8 -*-
# import matplotlib.pyplot as plt
# plt.title('CV_Score(top 30)')
# plt.rcParams['figure.figsize'] = (10, 8.0) # 设置figure_size尺寸
# plt.barh(cv_feature_sort[0:30], cv_feature_score[0:30],tick_label = cv_feature_sort[0:30])

# plt.tick_params(labelsize=8)
# plt.show()

# %%
# cv_feature_score

# %%
# #y_values = data [ target ]
# from scipy.stats import pearsonr
# y_values = y
# pearsonr_feature_impotance = [( column, pearsonr ( data[column], y_values) [0]) for column in features ]
# pearsonr_feature_impotance . sort (key=lambda x: abs(x [1]) , reverse =True)
# pearson_sorted_attrs = [item[0] for item in pearsonr_feature_impotance ]
# pearson_ranking = [ pearson_sorted_attrs . index(x) + 1 for x in features ]
# print ("# Pearson result")
# # print (pearson_ranking)
# # print ( pearsonr_feature_impotance )

# %%
# pearsonr_feature_impotance[0][0]

# %%
# pearsonr_feature_sort = []
# pearsonr_feature_score = []
# for i in range(0, len(pearsonr_feature_impotance)):
#     pearsonr_feature_sort.append(pearsonr_feature_impotance[i][0])
#     pearsonr_feature_score.append(pearsonr_feature_impotance[i][1])

# %%
# plt.title('Pearsonr_Score(top 30)')
# plt.rcParams['figure.figsize'] = (10, 8.0) # 设置figure_size尺寸
# plt.barh(pearsonr_feature_sort[0:30], pearsonr_feature_score[0:30],tick_label = pearsonr_feature_sort[0:30])

# plt.tick_params(labelsize=8)
# plt.show()

# %%
# from sklearn.preprocessing import Normalizer
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# data = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)
# data.describe()

# %%
# RF (Random Forest) feature ranking
from sklearn .ensemble import RandomForestRegressor
y_values = label
rf = RandomForestRegressor(n_estimators=500, n_jobs=-1)
rf.fit ( data.loc [:, features], y_values)
rf_scores = rf.feature_importances_
# print (rf_scores)

# %%
rf_feature_importance = []
for i in range(0, len(features)):
    rf_feature_importance.append((features[i], rf_scores[i]))
rf_feature_importance.sort(key=lambda x: (-x[1], x[0]))

# %%
# rf_feature_importance

# %%
rf_feature_sort = []
rf_feature_score = []
for i in range(0, len(rf_feature_importance)):
    rf_feature_sort.append(rf_feature_importance[i][0])
    rf_feature_score.append(rf_feature_importance[i][1])

# %%
plt.title('rf_Score(top 30)')
plt.rcParams['figure.figsize'] = (10, 8.0) # 设置figure_size尺寸
plt.barh(rf_feature_sort[0:30], rf_feature_score[0:30],tick_label = rf_feature_sort[0:30])

plt.tick_params(labelsize=8)
plt.show()

# %%
data_range = pd.read_csv('../data/data_range.csv', index_col = 0)

# %%
data_range = data_range.T

# %%
data_rf = pd.DataFrame(data, columns = rf_feature_sort[0:30])
data_rf = data_rf.T
data_rf['feature_importance'] = rf_feature_score[0:30]

data_rf['Product_RON_loss'] = label

# %%
data_rf_save = pd.DataFrame(data, columns = rf_feature_sort[0:30])
data_rf_save['Product_RON_loss'] = label
data_rf_save
# Out:
#      S-ZORB.AT_5201.PV  S-ZORB.DT_2001.DACA  S-ZORB.TE_5201.DACA  \
# 0            -0.110001            93.428016            44.920345
# 1             0.241799            94.420340            49.961387
# 2            -0.040036            94.729605            49.754584
# 3            -0.199544            96.880334            50.039984
# 4            -0.187086            97.991173            49.900836
# ..                 ...                  ...                  ...
# 320           1.560697            47.000323            44.431741
# 321           2.037648            48.510221            47.705298
# 322           0.803333            48.867726            48.597363
# 323           0.773961            50.020782            47.845586
# 324           4.012046            51.735987            49.573222
#
#      S-ZORB.LT_3801.DACA  S-ZORB.TE_1107.DACA  S-ZORB.TE_1601.PV  \
# 0               1.246513           120.779735         362.857200
# 1               0.992477           121.358590         359.919150
# 2               1.089546           120.472435         362.121115
# 3               1.364642           123.650450         362.648960
# 4               1.034412           122.847625         365.797790
# ..                   ...                  ...                ...
# 320             0.025413           124.334542         366.261945
# 321             0.077742           123.030560         366.204050
# 322            -0.014480           122.736108         367.534803
# 323            -0.094022           123.123953         368.100762
# 324            -0.385746           124.205313         366.543420
#
#      S-ZORB.LC_5101.PV  S-ZORB.PDT_1003.DACA  S-ZORB.PDT_2906.DACA  \
# 0            49.916519              0.615028             -0.871243
# 1            49.955209              0.617141             -0.966408
# 2            50.215176              0.622869             -0.981256
# 3            49.877925              0.629283             -0.935252
# 4            49.900563              7.598486             -0.949490
# ..                 ...                   ...                   ...
# 320         598.017788              9.632140             -0.702960
# 321         568.550955              9.607235             -0.677588
# 322         626.531005              9.574362             -0.751475
# 323         629.323360              9.433388             -0.279253
# 324         625.876948              9.396593             -0.370621
#
#      S-ZORB.TC_2801.PV  ...  S-ZORB.FT_2302.DACA  S-ZORB.LC_3301.DACA  \
# 0           272.367985  ...            10.429666            49.996662
# 1           281.072710  ...            16.712831            50.501584
# 2           272.924330  ...            17.236491            50.014960
# 3           269.141545  ...             9.029102            50.032104
# 4           267.033390  ...            16.715901            50.014087
# ..                 ...  ...                  ...                  ...
# 320         290.046320  ...            48.116448            50.088672
# 321         286.308350  ...            47.338066            49.875656
# 322         288.879765  ...            50.650948            49.930400
# 323         284.760735  ...            49.249372            50.000428
# 324         297.013340  ...            51.586444            49.678956
#
#      S-ZORB.PT_2901.DACA  S-ZORB.FT_3702.DACA  Raw_Saturated_hydrocarbon  \
# 0             511.160055            42.506640                  53.230000
# 1             522.763125            42.166220                  52.300000
# 2             530.525395            41.537158                  52.300000
# 3             530.351410            34.625504                  52.300000
# 4             524.028675            37.327574                  52.242857
# ..                   ...                  ...                        ...
# 320           549.208265             9.878017                  47.190000
# 321           545.920045            45.250794                  47.190000
# 322           549.523365             0.045580                  47.190000
# 323           544.395062             0.013843                  46.720000
# 324           547.197785             0.340998                  46.720000
#
#      S-ZORB.TE_2103.PV  S-ZORB.AT_1001.DACA  Recycle_C  S-ZORB.TE_1001.PV  \
# 0           424.615900           130.358250       1.84          56.247024
# 1           420.953385           139.992470       0.55          56.917281
# 2           423.941065           139.878080       1.89          56.298314
# 3           423.722805           127.938755       0.98          61.001800
# 4           427.132000           128.254285       0.83          59.878874
# ..                 ...                  ...        ...                ...
# 320         424.567210           225.020775       1.28          72.644269
# 321         425.062968           224.013005       1.28          70.428077
# 322         425.390800           213.336115       3.34          69.643416
# 323         426.057338           208.649452       3.13          70.397828
# 324         425.160278           194.446975       4.82          69.928027
#
#      Product_RON_loss
# 0                1.38
# 1                1.18
# 2                1.38
# 3                1.38
# 4                1.28
# ..                ...
# 320              1.15
# 321              1.25
# 322              1.35
# 323              1.28
# 324              1.25
#
# [325 rows x 31 columns]

# %%
data_rf_save.to_excel('../data/rf_top_30_data_preprocess_45.xlsx')

# %%
data_rf_importance = pd.DataFrame(data, columns = rf_feature_sort[0:30])
data_rf_importance.drop(data_rf_importance.index, inplace=True)

# %%
data_rf_importance = data_rf_importance.T
data_rf_importance['feature_importance'] = rf_feature_score[0:30]

# %%
data_range = data_range.T

# %%
data_range
# Out:
#       S-ZORB.CAL_H2.PV S-ZORB.PDI_2102.PV S-ZORB.PT_2801.PV S-ZORB.FC_2801.PV  \
# name               氢油比            反应过滤器压差             还原器压力         还原器流化氢气流量
# range        0.20-0.37              10-35         2.35-2.70          600-1000
# unit               NaN                KPa               MPa             Nm3/h
# delta             0.01                1.0               0.1              50.0
# r1                 0.2               10.0              2.35             600.0
# r2                0.37               35.0               2.7            1000.0
#
#       S-ZORB.TE_2103.PV S-ZORB.TE_2005.PV S-ZORB.PT_2101.PV  \
# name            反应器上部温度           反应器底部温度           反应器顶部压力
# range           410-435           399-430         2.25-2.55
# unit                  ℃                 ℃               MPa
# delta               1.0               1.0               0.1
# r1                410.0             399.0              2.25
# r2                435.0             430.0              2.55
#
#       S-ZORB.PDT_2104.PV S-ZORB.SIS_PDT_2103B.PV S-ZORB.TC_2101.PV  ...  \
# name             反应器顶底压差                 反应过滤器压差            反吹氢气温度  ...
# range             50-110                  8-1500           165-250  ...
# unit                 KPa                     KPa                 ℃  ...
# delta                5.0                   100.0               2.0  ...
# r1                  50.0                     8.0             165.0  ...
# r2                 110.0                  1500.0             250.0  ...
#
#       S-ZORB.CAL_1.CANGLIANG.PV S-ZORB.FT_1006.DACA.PV S-ZORB.FT_5204.DACA.PV  \
# name                      再生器藏量          加氢裂化轻石脑油进装置流量              汽油产品去气分流量
# range                   1.2-3.6                0-12000                 0-2500
# unit                          t                    NaN                   kg/h
# delta                       0.2                  100.0                  100.0
# r1                          1.2                    0.0                    0.0
# r2                          3.6                12000.0                 2500.0
#
#       S-ZORB.FT_1006.TOTALIZERA.PV S-ZORB.FT_5204.TOTALIZERA.PV  \
# name               加氢裂化轻石脑油进装置累积流量                  汽油产品去气分累积流量
# range                  0-150000000                30000-3000000
# unit                           NaN                         kg/h
# delta                      10000.0                      10000.0
# r1                             0.0                      30000.0
# r2                     150000000.0                    3000000.0
#
#       S-ZORB.FT_1503.DACA.PV S-ZORB.FT_1503.TOTALIZERA.PV  \
# name       8.0MPa氢气至循环氢压缩机入口            8.0MPa氢气至循环氢压缩机入口
# range             60-5500000                   0-40000000
# unit                     NaN                          NaN
# delta                10000.0                      10000.0
# r1                      60.0                          0.0
# r2                 5500000.0                   40000000.0
#
#       S-ZORB.FT_1504.DACA.PV S-ZORB.FT_1504.TOTALIZERA.PV S-ZORB.PC_1001A.PV
# name       8.0MPa氢气至反吹氢压缩机出口            8.0MPa氢气至反吹氢压缩机出口        D101原料缓冲罐压力
# range            -14000-3500                   0-40000000           -125-0.5
# unit                     NaN                          NaN                NaN
# delta                 1000.0                      10000.0                0.5
# r1                  -14000.0                          0.0             -125.0
# r2                    3500.0                   40000000.0                0.5
#
# [6 rows x 354 columns]

# %%
data_rf_importance.drop('Raw_RON', inplace = True)
data_rf_importance.drop('Raw_Saturated_hydrocarbon', inplace = True)
data_rf_importance.drop('Recycle_S', inplace = True)

# %%
data_rf_importance = data_rf_importance.T

# %%
data_range_importance = data_range[data_rf_importance.columns.values.tolist()]

# %%
data_range_importance = data_range_importance.T

# %%
data_range_importance
# Out:
#                                                    name          range   unit  \
# S-ZORB.DT_2001.DACA                         R-101下部床层压降          0-120    NaN
# S-ZORB.LT_3801.DACA                             D-125液位   -0.85-(2.00)     mm
# S-ZORB.TE_5201.DACA                      A-202A/B出口总管温度         30-100      ℃
# S-ZORB.TE_1601.PV                               加热炉进口温度        350-400      ℃
# S-ZORB.LC_5101.PV                           塔顶回流罐D201液位         40-800     mm
# S-ZORB.TE_1107.DACA                       E-101D壳程出口管温度         50-150      ℃
# S-ZORB.PDT_3502.DACA                        ME-109过滤器差压           5-20    NaN
# S-ZORB.TC_2801.PV                                 还原器温度        200-350      ℃
# S-ZORB.TE_5202.PV                             精制汽油出装置温度          30-45      ℃
# S-ZORB.PDT_2906.DACA                        ME-108过滤器差压          -2-25    NaN
# S-ZORB.PDT_1003.DACA                      P-101B入口过滤器差压        -1.5-12    NaN
# S-ZORB.TE_1104.DACA                       E-101F管程出口管温度         50-400      ℃
# S-ZORB.FT_9301.PV                               蒸汽进装置流量         0-3500  Nm3/h
# S-ZORB.LI_9102.DACA                             D-204液位          10-90      %
# S-ZORB.LT_9101.DACA                          火炬罐D-206液位        -5-(35)    NaN
# S-ZORB.PDT_2503.DACA                       D-107底排放滑阀压差  -0.5-(400000)    NaN
# S-ZORB.LI_2107.DACA     TAG表和PID图未见PDI-2107点，是否为DI-2107         -3-(9)    NaN
# S-ZORB.PDT_2605.DACA                         R-102底喷头压差        -0.5-30    NaN
# S-ZORB.PT_2901.DACA                       ME-103反吹气总管压力        485-590    NaN
# S-ZORB.FT_2302.DACA                      D-105上跨接线松动风流量          0-250  Nm3/h
# S-ZORB.LC_1203.DACA                            D-121水液位          35-55      %
# S-ZORB.TC_2101.PV                                反吹氢气温度        165-250      ℃
# S-ZORB.LC_5102.DACA                           D-201水包界位          35-85    NaN
# S-ZORB.TE_5102.PV                               干气出装置温度          20-40      ℃
# S-ZORB.FT_9002.DACA                         D203出口燃料气流量        300-650  Nm3/h
# S-ZORB.LC_3301.DACA                          D123冷凝水罐液位          45-55      %
# S-ZORB.FT_1006.DACA.PV                    加氢裂化轻石脑油进装置流量        0-12000    NaN
#
#                          delta     r1        r2
# S-ZORB.DT_2001.DACA       10.0    0.0     120.0
# S-ZORB.LT_3801.DACA        0.2  -0.85       2.0
# S-ZORB.TE_5201.DACA        1.0   30.0     100.0
# S-ZORB.TE_1601.PV          1.0  350.0     400.0
# S-ZORB.LC_5101.PV         50.0   40.0     800.0
# S-ZORB.TE_1107.DACA        1.0   50.0     150.0
# S-ZORB.PDT_3502.DACA       1.0    5.0      20.0
# S-ZORB.TC_2801.PV          1.0  200.0     350.0
# S-ZORB.TE_5202.PV          1.0   30.0      45.0
# S-ZORB.PDT_2906.DACA       1.0   -2.0      25.0
# S-ZORB.PDT_1003.DACA       1.0   -1.5      12.0
# S-ZORB.TE_1104.DACA        1.0   50.0     400.0
# S-ZORB.FT_9301.PV         50.0    0.0    3500.0
# S-ZORB.LI_9102.DACA        5.0   10.0      90.0
# S-ZORB.LT_9101.DACA        5.0   -5.0      35.0
# S-ZORB.PDT_2503.DACA    1000.0   -0.5  400000.0
# S-ZORB.LI_2107.DACA        1.0   -3.0       9.0
# S-ZORB.PDT_2605.DACA       0.5   -0.5      30.0
# S-ZORB.PT_2901.DACA        1.0  485.0     590.0
# S-ZORB.FT_2302.DACA       20.0    0.0     250.0
# S-ZORB.LC_1203.DACA        2.0   35.0      55.0
# S-ZORB.TC_2101.PV          2.0  165.0     250.0
# S-ZORB.LC_5102.DACA        5.0   35.0      85.0
# S-ZORB.TE_5102.PV          1.0   20.0      40.0
# S-ZORB.FT_9002.DACA       30.0  300.0     650.0
# S-ZORB.LC_3301.DACA        5.0   45.0      55.0
# S-ZORB.FT_1006.DACA.PV   100.0    0.0   12000.0

# %%
data_range_importance['feature_importance'] = data_rf_importance.T['feature_importance']
data_range_importance
# Out:
#                                                    name          range   unit  \
# S-ZORB.DT_2001.DACA                         R-101下部床层压降          0-120    NaN
# S-ZORB.LT_3801.DACA                             D-125液位   -0.85-(2.00)     mm
# S-ZORB.TE_5201.DACA                      A-202A/B出口总管温度         30-100      ℃
# S-ZORB.TE_1601.PV                               加热炉进口温度        350-400      ℃
# S-ZORB.LC_5101.PV                           塔顶回流罐D201液位         40-800     mm
# S-ZORB.TE_1107.DACA                       E-101D壳程出口管温度         50-150      ℃
# S-ZORB.PDT_3502.DACA                        ME-109过滤器差压           5-20    NaN
# S-ZORB.TC_2801.PV                                 还原器温度        200-350      ℃
# S-ZORB.TE_5202.PV                             精制汽油出装置温度          30-45      ℃
# S-ZORB.PDT_2906.DACA                        ME-108过滤器差压          -2-25    NaN
# S-ZORB.PDT_1003.DACA                      P-101B入口过滤器差压        -1.5-12    NaN
# S-ZORB.TE_1104.DACA                       E-101F管程出口管温度         50-400      ℃
# S-ZORB.FT_9301.PV                               蒸汽进装置流量         0-3500  Nm3/h
# S-ZORB.LI_9102.DACA                             D-204液位          10-90      %
# S-ZORB.LT_9101.DACA                          火炬罐D-206液位        -5-(35)    NaN
# S-ZORB.PDT_2503.DACA                       D-107底排放滑阀压差  -0.5-(400000)    NaN
# S-ZORB.LI_2107.DACA     TAG表和PID图未见PDI-2107点，是否为DI-2107         -3-(9)    NaN
# S-ZORB.PDT_2605.DACA                         R-102底喷头压差        -0.5-30    NaN
# S-ZORB.PT_2901.DACA                       ME-103反吹气总管压力        485-590    NaN
# S-ZORB.FT_2302.DACA                      D-105上跨接线松动风流量          0-250  Nm3/h
# S-ZORB.LC_1203.DACA                            D-121水液位          35-55      %
# S-ZORB.TC_2101.PV                                反吹氢气温度        165-250      ℃
# S-ZORB.LC_5102.DACA                           D-201水包界位          35-85    NaN
# S-ZORB.TE_5102.PV                               干气出装置温度          20-40      ℃
# S-ZORB.FT_9002.DACA                         D203出口燃料气流量        300-650  Nm3/h
# S-ZORB.LC_3301.DACA                          D123冷凝水罐液位          45-55      %
# S-ZORB.FT_1006.DACA.PV                    加氢裂化轻石脑油进装置流量        0-12000    NaN
#
#                          delta     r1        r2  feature_importance
# S-ZORB.DT_2001.DACA       10.0    0.0     120.0            0.051978
# S-ZORB.LT_3801.DACA        0.2  -0.85       2.0            0.030315
# S-ZORB.TE_5201.DACA        1.0   30.0     100.0            0.027092
# S-ZORB.TE_1601.PV          1.0  350.0     400.0            0.026165
# S-ZORB.LC_5101.PV         50.0   40.0     800.0            0.025677
# S-ZORB.TE_1107.DACA        1.0   50.0     150.0            0.021357
# S-ZORB.PDT_3502.DACA       1.0    5.0      20.0            0.020052
# S-ZORB.TC_2801.PV          1.0  200.0     350.0            0.019201
# S-ZORB.TE_5202.PV          1.0   30.0      45.0            0.018931
# S-ZORB.PDT_2906.DACA       1.0   -2.0      25.0            0.016764
# S-ZORB.PDT_1003.DACA       1.0   -1.5      12.0            0.016500
# S-ZORB.TE_1104.DACA        1.0   50.0     400.0            0.015172
# S-ZORB.FT_9301.PV         50.0    0.0    3500.0            0.013345
# S-ZORB.LI_9102.DACA        5.0   10.0      90.0            0.011594
# S-ZORB.LT_9101.DACA        5.0   -5.0      35.0            0.011495
# S-ZORB.PDT_2503.DACA    1000.0   -0.5  400000.0            0.011201
# S-ZORB.LI_2107.DACA        1.0   -3.0       9.0            0.010309
# S-ZORB.PDT_2605.DACA       0.5   -0.5      30.0            0.009479
# S-ZORB.PT_2901.DACA        1.0  485.0     590.0            0.008721
# S-ZORB.FT_2302.DACA       20.0    0.0     250.0            0.008604
# S-ZORB.LC_1203.DACA        2.0   35.0      55.0            0.008576
# S-ZORB.TC_2101.PV          2.0  165.0     250.0            0.008330
# S-ZORB.LC_5102.DACA        5.0   35.0      85.0            0.008199
# S-ZORB.TE_5102.PV          1.0   20.0      40.0            0.007979
# S-ZORB.FT_9002.DACA       30.0  300.0     650.0            0.007968
# S-ZORB.LC_3301.DACA        5.0   45.0      55.0            0.007861
# S-ZORB.FT_1006.DACA.PV   100.0    0.0   12000.0            0.007679

# %%
data_range_importance = data_range_importance.T

# %%
data_range_importance.to_csv('../data/data_rf_feature_28_importance.csv')

# %%
data_range_importance
# Out:
#                    S-ZORB.DT_2001.DACA S-ZORB.LT_3801.DACA  \
# name                       R-101下部床层压降             D-125液位
# range                            0-120        -0.85-(2.00)
# unit                               NaN                  mm
# delta                             10.0                 0.2
# r1                                 0.0               -0.85
# r2                               120.0                 2.0
# feature_importance           0.0519781           0.0303149
#
#                    S-ZORB.TE_5201.DACA S-ZORB.TE_1601.PV S-ZORB.LC_5101.PV  \
# name                    A-202A/B出口总管温度           加热炉进口温度       塔顶回流罐D201液位
# range                           30-100           350-400            40-800
# unit                                 ℃                 ℃                mm
# delta                              1.0               1.0              50.0
# r1                                30.0             350.0              40.0
# r2                               100.0             400.0             800.0
# feature_importance           0.0270917         0.0261654         0.0256775
#
#                    S-ZORB.TE_1107.DACA S-ZORB.PDT_3502.DACA S-ZORB.TC_2801.PV  \
# name                     E-101D壳程出口管温度          ME-109过滤器差压             还原器温度
# range                           50-150                 5-20           200-350
# unit                                 ℃                  NaN                 ℃
# delta                              1.0                  1.0               1.0
# r1                                50.0                  5.0             200.0
# r2                               150.0                 20.0             350.0
# feature_importance            0.021357            0.0200525         0.0192007
#
#                    S-ZORB.TE_5202.PV S-ZORB.PDT_2906.DACA  ...  \
# name                       精制汽油出装置温度          ME-108过滤器差压  ...
# range                          30-45                -2-25  ...
# unit                               ℃                  NaN  ...
# delta                            1.0                  1.0  ...
# r1                              30.0                 -2.0  ...
# r2                              45.0                 25.0  ...
# feature_importance         0.0189311            0.0167638  ...
#
#                    S-ZORB.PDT_2605.DACA S-ZORB.PT_2901.DACA  \
# name                         R-102底喷头压差       ME-103反吹气总管压力
# range                           -0.5-30             485-590
# unit                                NaN                 NaN
# delta                               0.5                 1.0
# r1                                 -0.5               485.0
# r2                                 30.0               590.0
# feature_importance           0.00947915          0.00872076
#
#                    S-ZORB.FT_2302.DACA S-ZORB.LC_1203.DACA S-ZORB.TC_2101.PV  \
# name                    D-105上跨接线松动风流量            D-121水液位            反吹氢气温度
# range                            0-250               35-55           165-250
# unit                             Nm3/h                   %                 ℃
# delta                             20.0                 2.0               2.0
# r1                                 0.0                35.0             165.0
# r2                               250.0                55.0             250.0
# feature_importance          0.00860444          0.00857566        0.00833001
#
#                    S-ZORB.LC_5102.DACA S-ZORB.TE_5102.PV S-ZORB.FT_9002.DACA  \
# name                         D-201水包界位           干气出装置温度         D203出口燃料气流量
# range                            35-85             20-40             300-650
# unit                               NaN                 ℃               Nm3/h
# delta                              5.0               1.0                30.0
# r1                                35.0              20.0               300.0
# r2                                85.0              40.0               650.0
# feature_importance          0.00819869        0.00797929          0.00796807
#
#                    S-ZORB.LC_3301.DACA S-ZORB.FT_1006.DACA.PV
# name                        D123冷凝水罐液位          加氢裂化轻石脑油进装置流量
# range                            45-55                0-12000
# unit                                 %                    NaN
# delta                              5.0                  100.0
# r1                                45.0                    0.0
# r2                                55.0                12000.0
# feature_importance          0.00786097             0.00767922
#
# [7 rows x 27 columns]

# %%
data_rf.to_excel('../data/rf_top_30_data_preprocess_45.xlsx')

# %%
# # MIC (Maximal Information Coefficient ) feature ranking
# from minepy import MINE

# mine = MINE()
# mic_scores = []
# data_s = data.sample(frac =0.001)
# print (data_s.shape)
# # for attr in features :
# #     print(attr)
# mine.compute_score(data_s.loc [:, attr], y_values)
# mic_scores.append(mine.mic())
# mic_result = sorted ( list ( zip ( features , mic_scores) ) , key=operator . itemgetter (1) , reverse =True)
# mic_sorted_attrs = [x[0] for x in mic_result ]
# mic_ranking = [ mic_sorted_attrs . index(x) + 1 for x in features ]
# # print ("# MIC result")
# # print ( mic_sorted_attrs )
# # print (mic_ranking)

# %%
# Catboost feature ranking
import catboost as cat
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
train_data, test_data, train_y, test_y = train_test_split(data, label, test_size = 0.3)
# eval_set = list(test_y)

# %%
crf = cat.CatBoostRegressor(
iterations =1200,
depth=10,
learning_rate =0.02,
verbose=100,
loss_function ='RMSE',
eval_metric ='RMSE',
# early_stopping_rounds =100,
random_seed=2019,
# task_type='GPU'
# bootstrap_type ='Poisson',
# devices='0'
)
crf.fit (train_data, train_y, eval_set = (test_data, test_y)) 
cat_ranking = [( y, x) for x, y in zip( data .columns, crf.feature_importances_ )]
cat_ranking.sort()
# print(cat_ranking )
# Out:
# 0:	learn: 1.2533882	test: 1.2760796	best: 1.2760796 (0)	total: 279ms	remaining: 5m 34s
# 100:	learn: 0.3149847	test: 0.4031222	best: 0.4031222 (100)	total: 17.6s	remaining: 3m 11s
# 200:	learn: 0.1565411	test: 0.2594412	best: 0.2594412 (200)	total: 34.6s	remaining: 2m 51s
# 300:	learn: 0.1364134	test: 0.2399007	best: 0.2399007 (300)	total: 51.3s	remaining: 2m 33s
# 400:	learn: 0.1281157	test: 0.2360208	best: 0.2360208 (400)	total: 1m 7s	remaining: 2m 13s
# 500:	learn: 0.1207039	test: 0.2333185	best: 0.2333185 (500)	total: 1m 24s	remaining: 1m 57s
# 600:	learn: 0.1164409	test: 0.2322483	best: 0.2322483 (600)	total: 1m 41s	remaining: 1m 40s
# 700:	learn: 0.1075742	test: 0.2315409	best: 0.2315409 (700)	total: 1m 58s	remaining: 1m 24s
# 800:	learn: 0.0938455	test: 0.2311604	best: 0.2311204 (799)	total: 2m 15s	remaining: 1m 7s
# 900:	learn: 0.0742580	test: 0.2305686	best: 0.2303321 (877)	total: 2m 33s	remaining: 50.9s
# 1000:	learn: 0.0551204	test: 0.2316719	best: 0.2302822 (916)	total: 2m 51s	remaining: 34s
# 1100:	learn: 0.0400580	test: 0.2318879	best: 0.2302822 (916)	total: 3m 8s	remaining: 17s
#
# bestTest = 0.2302822324
# bestIteration = 916
#
# Shrink model to first 917 iterations.

# %%
pred = crf.predict(test_data)

# %%
cat_ranking.sort(reverse = True)

# %%
# cat_ranking
import sklearn
sklearn.metrics.mean_squared_error(pred, test_y)
# Out:
# 0.05302991095059253

# %%
cat_feature_sort = []
cat_feature_score = []
for i in range(0, len(cat_ranking)):
    cat_feature_sort.append(cat_ranking[i][1])
    cat_feature_score.append(cat_ranking[i][0])

# %%
plt.title('Catboost_Score(top 30)')
plt.rcParams['figure.figsize'] = (10, 8.0) # 设置figure_size尺寸
plt.barh(cat_feature_sort[0:30], cat_feature_score[0:30],tick_label = cat_feature_sort[0:30])

plt.tick_params(labelsize=8)
plt.show()

# %%
data_cat = pd.DataFrame(data, columns = cat_feature_sort[0:5])
data_cat['Product_RON_loss'] = label

# %%
data_cat.to_excel('../data/cat_top_5_data_preprocess_45.xlsx')
data_cat
# Out:
#      S-ZORB.FT_1003.PV  S-ZORB.TE_1601.PV  S-ZORB.TC_2607.PV  \
# 0            -1.314845          -0.684876          -1.158649
# 1            -1.873857          -1.780020          -2.760490
# 2            -1.743655          -0.959248           1.622921
# 3            -0.491029          -0.762496          -0.288081
# 4            -0.011867           0.411215           0.244624
# ..                 ...                ...                ...
# 320           0.252805           0.584226          -1.560582
# 321           0.224107           0.562646          -2.146914
# 322           0.164835           1.058678          -0.298725
# 323           0.033673           1.269637           0.238629
# 324          -1.161188           0.689145          -1.183446
#
#      S-ZORB.AT_1001.DACA  S-ZORB.FT_2431.DACA  Product_RON_loss
# 0              -1.736451             1.055984              1.38
# 1              -1.581063             0.120501              1.18
# 2              -1.582908             0.243755              1.38
# 3              -1.775474             0.726474              1.38
# 4              -1.770385             0.297842              1.28
# ..                   ...                  ...               ...
# 320            -0.209663            -0.662029              1.15
# 321            -0.225917            -0.509760              1.25
# 322            -0.398122            -0.861728              1.35
# 323            -0.473712            -0.906397              1.28
# 324            -0.702780            -0.618272              1.25
#
# [325 rows x 6 columns]

# %%
import missingno as msno
msno.matrix(data);
