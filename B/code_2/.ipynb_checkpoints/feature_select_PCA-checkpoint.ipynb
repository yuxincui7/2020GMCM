# %%
#Feature reduce - Option 1: corr with Product_RON_loss

# %%
import pandas as pd
import numpy as np

# %%
data
# Out:
#      Raw_S_content  Raw_RON  Raw_Saturated_hydrocarbon  Raw_Aromatics  \
# 0       188.000000     90.6                  53.230000      22.370000
# 1       169.000000     90.5                  52.300000      21.300000
# 2       177.000000     90.7                  52.300000      21.385714
# 3       159.000000     90.4                  52.300000      21.600000
# 4       173.000000     89.6                  52.242857      21.085714
# ..             ...      ...                        ...            ...
# 320     271.428571     89.2                  47.190000      21.510000
# 321     271.428571     89.2                  47.190000      21.510000
# 322     271.428571     89.4                  47.190000      21.510000
# 323     266.000000     89.4                  46.720000      19.500000
# 324     266.000000     89.9                  46.720000      19.500000
#
#      Raw_Bromine_value  Raw_Density  Product_S_content  Spent_C  Spent_S  \
# 0            61.487143   726.085714                3.2     2.32     7.30
# 1            61.880000   731.300000                3.2     2.37     7.34
# 2            61.722857   729.614286                3.2     2.43     7.27
# 3            61.330000   725.400000                3.2     3.08     7.35
# 4            61.332857   725.428571                3.2     2.45     6.58
# ..                 ...          ...                ...      ...      ...
# 320          52.020000   725.200000                3.2     2.39    12.24
# 321          52.020000   725.200000                3.2     9.09    11.82
# 322          52.020000   725.200000                3.2     5.72    10.96
# 323          45.450000   730.000000                3.6     4.33     9.71
# 324          45.450000   730.000000                3.2     8.33    11.16
#
#      Recycle_C  ...  S-ZORB.AT-0001.DACA.PV  S-ZORB.AT-0003.DACA.PV  \
# 0         1.84  ...                0.521452                0.459009
# 1         0.55  ...                0.523177                0.459806
# 2         1.89  ...                0.528869                0.475716
# 3         0.98  ...                0.531558                0.460900
# 4         0.83  ...                0.522472                0.468744
# ..         ...  ...                     ...                     ...
# 320       1.28  ...                0.545854                1.198154
# 321       1.28  ...                0.535388                0.935071
# 322       3.34  ...                0.544487                1.919862
# 323       3.13  ...                0.556830                1.464891
# 324       4.82  ...                0.556529                3.231192
#
#      S-ZORB.FT_1204.DACA.PV  S-ZORB.FT_5102.DACA.PV  S-ZORB.CAL.LEVEL.PV  \
# 0                 18.292067               69.606565            76.849853
# 1                 19.842605               67.113043            76.184425
# 2                 26.994896               68.613427            75.966841
# 3                 26.324458               69.714368            76.790042
# 4                 30.224367               68.593075            76.539556
# ..                      ...                     ...                  ...
# 320               53.423653               64.004581            79.398457
# 321               76.606090               70.896823            79.461877
# 322               53.357489                3.665722            79.441724
# 323               61.547225               20.237576            79.181882
# 324                2.737464                6.413762            78.988005
#
#      S-ZORB.FT_1006.DACA.PV  S-ZORB.FT_5204.DACA.PV  S-ZORB.FT_1503.DACA.PV  \
# 0                6368.74700              233.310805              2216.40935
# 1                6360.64530              242.369205              2370.58740
# 2                6504.96490              233.076925              2326.46535
# 3                6506.82495              238.349935              2495.22360
# 4                6560.24225              236.576220              2807.78910
# ..                      ...                     ...                     ...
# 320              8328.97475              150.441617              2177.55770
# 321              8457.86080              148.748365              2177.55770
# 322              8246.20925              150.095445              2177.55770
# 323              7998.80235              149.533987              2177.55770
# 324              8379.94380              158.409230              2177.55770
#
#      S-ZORB.FT_1504.DACA.PV  Product_RON_loss
# 0                1840.14470              1.38
# 1                1641.73260              1.18
# 2                1600.67575              1.38
# 3                1563.71215              1.38
# 4                1554.35740              1.28
# ..                      ...               ...
# 320              2538.53845              1.15
# 321              2538.53845              1.25
# 322              2538.53845              1.35
# 323              2538.53845              1.28
# 324              2538.53845              1.25
#
# [325 rows x 166 columns]

# %%
table_path = "../data/data_num_325_fea_reduce.csv"
PCA_table_path = "../data/data_num_325_fea_PCA.csv"
data = pd.read_csv(table_path, index_col = 0)

X = data.drop("Product_RON_loss", 1)
y = data["Product_RON_loss"]

# %%
#Feature Scaling - Mean to 0, variance to 1
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)
print(X.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cdeeb5825cad> in <module>
#       3
#       4 scaler = StandardScaler()
# ----> 5 X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)
#       6 print(X.shape)
#
# NameError: name 'pd' is not defined
