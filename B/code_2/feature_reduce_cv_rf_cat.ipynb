# %%
#特征评价关键代码
import os
import matplotlib . pyplot as plt
import numpy as np
import pandas as pd

# %%
# data = pd.read_excel('../data/data_preprocess_only_45.xlsx')
# del data['Unnamed: 0']
# label = data['Product_RON_loss']
# del data['Product_RON_loss']

# %%
data = pd.read_csv('../data/data_num_325_fea_reduce.csv') #164对应只做45的， 165对应small,large且做了45
rf_path = '../data/data_num_325_fea_30_rf.csv'
cat_path = '../data/data_num_325_fea_30_cat.csv'
label = data['Product_RON_loss']
del data['Unnamed: 0']
del data['Product_RON_loss']

# %%
data.describe()
# Out:
#        Raw_S_content     Raw_RON  Raw_Saturated_hydrocarbon  Raw_Aromatics  \
# count     325.000000  325.000000                 325.000000     325.000000
# mean      229.548904   89.733538                  52.676228      21.949782
# std        65.752227    0.889764                   4.584314       1.823616
# min        57.000000   87.200000                  43.240000      16.822222
# 25%       185.000000   89.200000                  49.610000      20.690000
# 50%       240.285714   89.800000                  53.250000      21.890000
# 75%       271.428571   90.300000                  56.100000      23.300000
# max       392.000000   91.700000                  63.400000      26.200000
#
#        Raw_Bromine_value  Raw_Density  Product_S_content     Spent_C  \
# count         325.000000   325.000000         325.000000  325.000000
# mean           54.526661   726.755265           3.910154    3.030794
# std             6.818416     4.262181           1.265322    1.722995
# min            36.520000   715.100000           3.200000    1.010000
# 25%            48.750000   724.200000           3.200000    1.850000
# 50%            53.980000   726.300000           3.200000    2.390000
# 75%            60.190000   729.500000           4.200000    3.610000
# max            70.500000   738.700000           8.600000    9.090000
#
#           Spent_S   Recycle_C  ...  S-ZORB.TE_1102.DACA  \
# count  325.000000  325.000000  ...           325.000000
# mean     8.063265    1.507521  ...           426.623764
# std      2.132002    0.966428  ...             1.759060
# min      2.940000    0.250000  ...           420.898430
# 25%      6.990000    0.933333  ...           426.075162
# 50%      8.400000    1.280000  ...           427.171300
# 75%      9.370000    1.670000  ...           427.171300
# max     14.310000    5.190000  ...           432.095332
#
#        S-ZORB.AT-0001.DACA.PV  S-ZORB.AT-0003.DACA.PV  S-ZORB.FT_1204.DACA.PV  \
# count              325.000000              325.000000              325.000000
# mean                 2.547025                1.131551               51.913266
# std                  2.684052                1.147907               18.092283
# min                  0.498255                0.447884                0.889900
# 25%                  0.534488                0.464989               38.945485
# 50%                  0.555710                0.472675               51.672012
# 75%                  5.123928                1.391713               62.998978
# max                  7.155496                4.493657              106.657364
#
#        S-ZORB.FT_5102.DACA.PV  S-ZORB.CAL.LEVEL.PV  S-ZORB.FT_1006.DACA.PV  \
# count              325.000000           325.000000              325.000000
# mean                43.675943          1917.403402             4843.993930
# std                 48.877772          5287.204185             2359.134691
# min                  0.000000         -4269.455900                0.000000
# 25%                  0.000000            78.928243             4215.424100
# 50%                 64.004581            80.502553             5094.966775
# 75%                 67.964399            84.508473             6129.741900
# max                227.282440         18433.389250            11320.456750
#
#        S-ZORB.FT_5204.DACA.PV  S-ZORB.FT_1503.DACA.PV  S-ZORB.FT_1504.DACA.PV
# count              325.000000              325.000000              325.000000
# mean               143.854913             2190.862732             2409.550662
# std                137.450504              418.047777              452.316109
# min                  0.000000              979.564940             1222.663100
# 25%                  0.000000             1887.742875             2329.794550
# 50%                142.936557             2177.557700             2538.538450
# 75%                203.804645             2496.749950             2702.628700
# max                589.154615             3334.904725             3104.564825
#
# [8 rows x 165 columns]

# %%
# from sklearn.preprocessing import Normalizer
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# data = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)
# data.describe()

# %%
features = data.columns.values.tolist()

# %%
# # CV ranking
# cv_feature_importance = [( column, np. std ( data [column])/abs(np.mean(data[column]))) for column in features ]
# cv_feature_importance.sort (key=lambda x: x [1], reverse =True)
# cv_sorted_attrs = [item[0] for item in cv_feature_importance ]
# cv_ranking = [ cv_sorted_attrs . index(x) + 1 for x in features ]
# print ("# CV result")
# # print (cv_ranking)
# # print ( cv_feature_importance )

# %%
# cv_feature_sort = []
# cv_feature_score = []
# for i in range(0, len(cv_feature_importance)):
#     cv_feature_sort.append(cv_feature_importance[i][0])
#     cv_feature_score.append(cv_feature_importance[i][1])

# %%
# data_cv = pd.DataFrame(data, columns = cv_feature_sort[0:30]) 
# data_cv['Product_RON_loss'] = label

# %%
# data_cv.describe()

# %%
# data_cv.to_excel('../data/cv_top_30_data_process_45_var_corr_168.xlsx')

# %%
# # -*- coding: utf-8 -*-
# import matplotlib.pyplot as plt
# plt.title('CV_Score(top 30)')
# plt.rcParams['figure.figsize'] = (10, 8.0) # 设置figure_size尺寸
# plt.barh(cv_feature_sort[0:30], cv_feature_score[0:30],tick_label = cv_feature_sort[0:30])

# plt.tick_params(labelsize=8)
# plt.show()

# %%
# cv_feature_score

# %%
# #y_values = data [ target ]
# from scipy.stats import pearsonr
# y_values = y
# pearsonr_feature_impotance = [( column, pearsonr ( data[column], y_values) [0]) for column in features ]
# pearsonr_feature_impotance . sort (key=lambda x: abs(x [1]) , reverse =True)
# pearson_sorted_attrs = [item[0] for item in pearsonr_feature_impotance ]
# pearson_ranking = [ pearson_sorted_attrs . index(x) + 1 for x in features ]
# print ("# Pearson result")
# # print (pearson_ranking)
# # print ( pearsonr_feature_impotance )

# %%
# pearsonr_feature_impotance[0][0]

# %%
# pearsonr_feature_sort = []
# pearsonr_feature_score = []
# for i in range(0, len(pearsonr_feature_impotance)):
#     pearsonr_feature_sort.append(pearsonr_feature_impotance[i][0])
#     pearsonr_feature_score.append(pearsonr_feature_impotance[i][1])

# %%
# plt.title('Pearsonr_Score(top 30)')
# plt.rcParams['figure.figsize'] = (10, 8.0) # 设置figure_size尺寸
# plt.barh(pearsonr_feature_sort[0:30], pearsonr_feature_score[0:30],tick_label = pearsonr_feature_sort[0:30])

# plt.tick_params(labelsize=8)
# plt.show()

# %%
# from sklearn.preprocessing import Normalizer
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# data = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)
# data.describe()

# %%
# RF (Random Forest) feature ranking
from sklearn .ensemble import RandomForestRegressor
y_values = label
rf = RandomForestRegressor(n_estimators=500, n_jobs=-1)
rf.fit ( data.loc [:, features], y_values)
rf_scores = rf.feature_importances_
# print (rf_scores)

# %%
rf_feature_importance = []
for i in range(0, len(features)):
    rf_feature_importance.append((features[i], rf_scores[i]))
rf_feature_importance.sort(key=lambda x: (-x[1], x[0]))

# %%
# rf_feature_importance

# %%
rf_feature_sort = []
rf_feature_score = []
for i in range(0, len(rf_feature_importance)):
    rf_feature_sort.append(rf_feature_importance[i][0])
    rf_feature_score.append(rf_feature_importance[i][1])

# %%
plt.title('rf_Score(top 30)')
plt.rcParams['figure.figsize'] = (10, 8.0) # 设置figure_size尺寸
plt.barh(rf_feature_sort[0:30], rf_feature_score[0:30],tick_label = rf_feature_sort[0:30])

plt.tick_params(labelsize=8)
plt.show()

# %%
data_range = pd.read_csv('../data/data_range.csv', index_col = 0)

# %%
data_range = data_range.T

# %%
data_rf = pd.DataFrame(data, columns = rf_feature_sort[0:30])
data_rf = data_rf.T
data_rf['feature_importance'] = rf_feature_score[0:30]

data_rf['Product_RON_loss'] = label

# %%
data_rf_save = pd.DataFrame(data, columns = rf_feature_sort[0:30])
data_rf_save['Product_RON_loss'] = label
data_rf_save
# Out:
#      S-ZORB.DT_2001.DACA  S-ZORB.PDT_1003.DACA  S-ZORB.AT_5201.PV  \
# 0              93.428016              0.615028          -0.110001
# 1              94.420340              0.617141           0.241799
# 2              94.729605              0.622869          -0.040036
# 3              96.880335              0.629283          -0.199544
# 4              97.991173              7.598486          -0.187086
# ..                   ...                   ...                ...
# 320            47.000323              9.632140           1.560697
# 321            48.510221              9.607235           2.037648
# 322            48.867726              9.574362           0.803333
# 323            50.020782              9.433388           0.773961
# 324            51.735987              9.396593           4.012046
#
#      S-ZORB.FC_1203.PV  S-ZORB.TE_1107.DACA  S-ZORB.FT_9301.PV  \
# 0            11.876378           120.779735        1458.339950
# 1            11.419075           121.358590        1142.179200
# 2            11.572593           120.472435        1025.874790
# 3            11.734053           123.650450         967.852340
# 4            11.673913           122.847625         932.608515
# ..                 ...                  ...                ...
# 320          10.381811           124.334542        1963.308525
# 321           9.995659           123.030560        1974.646925
# 322          10.195086           122.736107        1788.499125
# 323          10.412704           123.123952        1977.315600
# 324           9.855469           124.205312        1626.185125
#
#      S-ZORB.TC_2101.PV  S-ZORB.LT_3801.DACA  S-ZORB.PDT_3502.DACA  \
# 0           240.088445             1.246513              9.308272
# 1           239.809820             0.992477             10.611206
# 2           239.742695             1.089546              9.457125
# 3           239.732465             1.364642             10.058440
# 4           239.835635             1.034412             10.181999
# ..                 ...                  ...                   ...
# 320         244.986360             0.025413             10.128979
# 321         244.937650             0.077742             10.937725
# 322         245.025612            -0.014480             11.383706
# 323         244.818115            -0.094022             10.585208
# 324         244.914960            -0.385746             10.687697
#
#      S-ZORB.LI_9102.DACA  ...  S-ZORB.LC_3301.DACA  S-ZORB.PDT_2906.DACA  \
# 0              38.582684  ...            49.996662             -0.871243
# 1              28.822868  ...            50.501584             -0.966408
# 2              38.263087  ...            50.014959             -0.981256
# 3              52.806651  ...            50.032104             -0.935252
# 4              25.514757  ...            50.014087             -0.949490
# ..                   ...  ...                  ...                   ...
# 320            42.912789  ...            50.088672             -0.702960
# 321            66.449456  ...            49.875656             -0.677588
# 322            45.007163  ...            49.930400             -0.751475
# 323            42.173350  ...            50.000428             -0.279253
# 324            49.473894  ...            49.678956             -0.370621
#
#      S-ZORB.LT_9101.DACA  S-ZORB.PDT_2605.DACA  S-ZORB.PDT_2503.DACA  \
# 0              -1.798679              0.118129             -0.379637
# 1               0.578173              0.211532             -0.379253
# 2              -0.486859              0.331018             -0.379965
# 3              -0.697793              0.149623             -0.380382
# 4              -0.370695             -0.025154             -0.379375
# ..                   ...                   ...                   ...
# 320             2.216257              0.288261             -0.326847
# 321             3.306614             10.671572             -0.293121
# 322            -4.016465             13.136913             -0.290815
# 323            -4.021979              0.288261             -0.282910
# 324            -4.017217              8.511801             -0.281010
#
#      S-ZORB.AT_1001.DACA  Recycle_S  S-ZORB.TE_5007.DACA  S-ZORB.PDT_2104.PV  \
# 0             130.358250       5.98           142.426100          101.290580
# 1             139.992470       4.38           142.426100          101.544925
# 2             139.878080       5.82           142.426100          101.618320
# 3             127.938755       4.67           142.426100          105.029760
# 4             128.254285       4.52           142.426100          105.937455
# ..                   ...        ...                  ...                 ...
# 320           225.020775       6.08           142.837675           52.717846
# 321           224.013005       6.08           143.533160           54.426241
# 322           213.336115       7.41           143.403775           54.764742
# 323           208.649452       6.97           142.903283           55.948335
# 324           194.446975       8.72           144.373295           57.791767
#
#      Product_RON_loss
# 0                1.38
# 1                1.18
# 2                1.38
# 3                1.38
# 4                1.28
# ..                ...
# 320              1.15
# 321              1.25
# 322              1.35
# 323              1.28
# 324              1.25
#
# [325 rows x 31 columns]

# %%
data_rf_save.to_csv(rf_path)

# %%
# data_rf_importance = pd.DataFrame(data, columns = rf_feature_sort[0:30])
# data_rf_importance.drop(data_rf_importance.index, inplace=True)

# %%
# data_rf_importance = data_rf_importance.T
# data_rf_importance['feature_importance'] = rf_feature_score[0:30]

# %%
# data_range = data_range.T

# %%
# data_range

# %%
# data_rf_importance.drop('Raw_RON', inplace = True)
# data_rf_importance.drop('Raw_Saturated_hydrocarbon', inplace = True)
# data_rf_importance.drop('Recycle_S', inplace = True)

# %%
# data_rf_importance = data_rf_importance.T

# %%
# data_range_importance = data_range[data_rf_importance.columns.values.tolist()]

# %%
# data_range_importance = data_range_importance.T

# %%
# data_range_importance

# %%
# data_range_importance['feature_importance'] = data_rf_importance.T['feature_importance']
# data_range_importance

# %%
# data_range_importance = data_range_importance.T

# %%
# data_range_importance.to_csv('../data/data_rf_feature_28_importance.csv')

# %%
# data_range_importance

# %%
# data_rf.to_excel('../data/rf_top_30_data_preprocess_45.xlsx')

# %%
# # MIC (Maximal Information Coefficient ) feature ranking
# from minepy import MINE

# mine = MINE()
# mic_scores = []
# data_s = data.sample(frac =0.001)
# print (data_s.shape)
# # for attr in features :
# #     print(attr)
# mine.compute_score(data_s.loc [:, attr], y_values)
# mic_scores.append(mine.mic())
# mic_result = sorted ( list ( zip ( features , mic_scores) ) , key=operator . itemgetter (1) , reverse =True)
# mic_sorted_attrs = [x[0] for x in mic_result ]
# mic_ranking = [ mic_sorted_attrs . index(x) + 1 for x in features ]
# # print ("# MIC result")
# # print ( mic_sorted_attrs )
# # print (mic_ranking)

# %%
# Catboost feature ranking
import catboost as cat
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
train_data, test_data, train_y, test_y = train_test_split(data, label, test_size = 0.3)
# eval_set = list(test_y)

# %%
crf = cat.CatBoostRegressor(
iterations =1200,
depth=10,
learning_rate =0.02,
verbose=100,
loss_function ='RMSE',
eval_metric ='RMSE',
# early_stopping_rounds =100,
random_seed=2019,
# task_type='GPU'
# bootstrap_type ='Poisson',
# devices='0'
)
crf.fit (train_data, train_y, eval_set = (test_data, test_y)) 
cat_ranking = [( y, x) for x, y in zip( data .columns, crf.feature_importances_ )]
cat_ranking.sort()
# print(cat_ranking )
# Out:
# 0:	learn: 0.2295399	test: 0.2132515	best: 0.2132515 (0)	total: 170ms	remaining: 3m 23s
# 100:	learn: 0.1473243	test: 0.2021733	best: 0.2021733 (100)	total: 6.81s	remaining: 1m 14s
# 200:	learn: 0.1008509	test: 0.1992697	best: 0.1991870 (196)	total: 13.5s	remaining: 1m 6s
# 300:	learn: 0.0728976	test: 0.1982333	best: 0.1982138 (287)	total: 20s	remaining: 59.8s
# 400:	learn: 0.0538574	test: 0.1967999	best: 0.1967999 (400)	total: 26.7s	remaining: 53.2s
# 500:	learn: 0.0362191	test: 0.1959820	best: 0.1959820 (500)	total: 33.4s	remaining: 46.5s
# 600:	learn: 0.0237366	test: 0.1955329	best: 0.1954859 (586)	total: 40s	remaining: 39.9s
# 700:	learn: 0.0164579	test: 0.1954377	best: 0.1953729 (643)	total: 46.6s	remaining: 33.2s
# 800:	learn: 0.0112455	test: 0.1955126	best: 0.1953729 (643)	total: 53.3s	remaining: 26.6s
# 900:	learn: 0.0076269	test: 0.1954610	best: 0.1953729 (643)	total: 60s	remaining: 19.9s
# 1000:	learn: 0.0052317	test: 0.1953568	best: 0.1953538 (996)	total: 1m 6s	remaining: 13.2s
# 1100:	learn: 0.0034831	test: 0.1953319	best: 0.1953319 (1100)	total: 1m 13s	remaining: 6.59s
# 1199:	learn: 0.0023448	test: 0.1953182	best: 0.1953129 (1191)	total: 1m 19s	remaining: 0us
#
# bestTest = 0.1953128754
# bestIteration = 1191
#
# Shrink model to first 1192 iterations.

# %%
pred = crf.predict(test_data)

# %%
cat_ranking.sort(reverse = True)

# %%
# cat_ranking
import sklearn
sklearn.metrics.mean_squared_error(pred, test_y)
# Out:
# 0.038147121059712574

# %%
cat_feature_sort = []
cat_feature_score = []
for i in range(0, len(cat_ranking)):
    cat_feature_sort.append(cat_ranking[i][1])
    cat_feature_score.append(cat_ranking[i][0])

# %%
plt.title('Catboost_Score(top 30)')
plt.rcParams['figure.figsize'] = (10, 8.0) # 设置figure_size尺寸
plt.barh(cat_feature_sort[0:30], cat_feature_score[0:30],tick_label = cat_feature_sort[0:30])

plt.tick_params(labelsize=8)
plt.show()

# %%
data_cat = pd.DataFrame(data, columns = cat_feature_sort[0:5])
data_cat['Product_RON_loss'] = label

# %%
data_cat.to_excel(cat_path)
data_cat
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# ~/.conda/envs/tf22_py38/lib/python3.8/site-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, **kwargs)
#     629                 try:
# --> 630                     engine = config.get_option("io.excel.{ext}.writer".format(ext=ext))
#     631                     if engine == "auto":
#
# ~/.conda/envs/tf22_py38/lib/python3.8/site-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     232     def __call__(self, *args, **kwds):
# --> 233         return self.__func__(*args, **kwds)
#     234
#
# ~/.conda/envs/tf22_py38/lib/python3.8/site-packages/pandas/_config/config.py in _get_option(pat, silent)
#     101 def _get_option(pat, silent=False):
# --> 102     key = _get_single_key(pat, silent)
#     103
#
# ~/.conda/envs/tf22_py38/lib/python3.8/site-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#      87             _warn_if_deprecated(pat)
# ---> 88         raise OptionError("No such keys(s): {pat!r}".format(pat=pat))
#      89     if len(keys) > 1:
#
# OptionError: "No such keys(s): 'io.excel.csv.writer'"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-19aa3c66d1a1> in <module>
# ----> 1 data_cat.to_excel(cat_path)
#       2 data_cat
#
# ~/.conda/envs/tf22_py38/lib/python3.8/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2248             inf_rep=inf_rep,
#    2249         )
# -> 2250         formatter.write(
#    2251             excel_writer,
#    2252             sheet_name=sheet_name,
#
# ~/.conda/envs/tf22_py38/lib/python3.8/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# --> 730             writer = ExcelWriter(_stringify_path(writer), engine=engine)
#     731             need_save = True
#     732
#
# ~/.conda/envs/tf22_py38/lib/python3.8/site-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, **kwargs)
#     632                         engine = _get_default_writer(ext)
#     633                 except KeyError:
# --> 634                     raise ValueError("No engine for filetype: '{ext}'".format(ext=ext))
#     635             cls = get_writer(engine)
#     636
#
# ValueError: No engine for filetype: 'csv'

# %%
# import missingno as msno
# msno.matrix(data);
